# %%
import altair as alt
import polars as pl
import yaml

# Output path
output_dir = "/master/abagwell/variant-analysis/results/rhesus/heterozygosity/plots"

# Seq type to filter on. WES and WGS are not compatible. WES has higher heterozygosity
seq_type = "WGS"

# Read config file. User should update this file path as needed
configfile = "/master/abagwell/workspace/github_project/variant-analysis/config/rhesus.yaml"
with open(configfile, 'r') as file:
    config = yaml.safe_load(file)

# Load colors
colors = pl.read_csv(config["colors"], separator="\t", schema_overrides={"Cohort": pl.String})

# Load cohorts
colonies_file = config["cohorts"]
colonies = pl.read_csv(colonies_file, separator="\t", comment_prefix="#", schema_overrides={"Id": pl.String}).select("Id", "Cohort").unique()

# %%
# Read heterozygosity data
df = pl.read_csv(config["results"] + 'heterozygosity/gvcf_counts.het',
    separator='\t',
    schema_overrides={'SAMPLE': pl.String}
).with_columns(
    Seq = pl.col('SAMPLE').str.slice(0, 3),
    Indiv = pl.col('SAMPLE').str.split('_').list.get(0).str.slice(3),
    Heterozygosity = pl.col('HET').truediv('TOTAL')
).drop("SAMPLE"
# Filter to one type of sequencing. WES does give higher heterozygosity than WGS
).filter(
    pl.col("Seq") == seq_type
# Deduplicate individuals
).group_by('Indiv').agg(pl.first('*')
# Join cohort info
).join(colonies, left_on='Indiv', right_on='Id'
).with_columns(
    pl.col('Cohort').cast(pl.Enum( 
        list(colors["Cohort"])
    )),
).group_by("Cohort").agg("Heterozygosity", 'Indiv'
).with_row_index("pop_idx", offset=1).with_columns(
    # Find which are year ranges
    is_year = pl.col("Cohort").cast(pl.String).str.contains("-").not_().cast(pl.Int8)
).with_columns(
    # Set the index of year ranges to 0
    pl.col("pop_idx").mul("is_year")
).drop("is_year").sort("Cohort"
).group_by(
    # Create color index
    "pop_idx", maintain_order=True
).agg('*').with_row_index("color_idx").drop("pop_idx").explode(pl.exclude("color_idx")).explode(pl.exclude("Cohort", "color_idx"))

# %%
# For seeing the number of individuals in each cohort
df.group_by("Cohort").agg(pl.len())

# %%
# Read pedigree to find trios
pedigree = pl.read_csv(config["demographics"], separator="\t", columns=['Id', 'Sire', 'Dam'],
    schema_overrides={'Id': pl.String, 'Sire': pl.String, 'Dam': pl.String})

# Create dataframe for plotting trios
df2 = df.join(
    # Add pedigree information
    pedigree, left_on='Indiv', right_on='Id', how='left'
).filter(
    # Keep only P51 offspring
    pl.col("Cohort") == "P51 offspring"  # TODO: Generalize
).sort("Heterozygosity", descending=True).with_row_index("trio_idx"
).unpivot(["Indiv", "Sire", "Dam"], index="trio_idx", variable_name="Relation", value_name="Id").join(
    # Rejoin
    df, left_on='Id', right_on='Indiv', how='left'
)

# %%
# Find U42 sires
sires_df = df2.filter(pl.col("Relation") == "Sire").select("Id").sort("Id").with_columns(
    Cohort = pl.lit("U42 sires")
)

# Find CPRC dams
dams_df = df2.filter(pl.col("Relation") == "Dam").select("Id").sort("Id").with_columns(
    Cohort = pl.lit("CPRC dams")
)

pl.concat([colonies, sires_df, dams_df])

# %%
colonies

# %%
# Add parental cohorts to dataframe. These parents will be included in both their original and new cohorts
df_with_parental_cohorts = pl.concat([colonies, sires_df, dams_df]
).join(df.select("color_idx", "Indiv", "Heterozygosity"), left_on="Id", right_on="Indiv", how="left"
).filter(pl.col("Heterozygosity").is_not_null()).unique().rename({"Id": "Indiv"})

df_with_parental_cohorts

# %%
df_with_parental_cohorts.group_by("Cohort").agg(pl.len())

# %%
barplot = alt.Chart(df_with_parental_cohorts).mark_boxplot().encode(
    alt.X('Cohort', title='Cohort', sort=colors["Cohort"]),
    alt.Y('Heterozygosity', title='Heterozygosity').scale(zero=False), 
    alt.Color('Cohort:N', legend=None,).scale(
        domain = list(colors["Cohort"]),
        range = list(colors["Color"])
    ),
    tooltip=[
        alt.Tooltip('Indiv')
    ]
).properties(
    title="Heterozygosity"
)

barplot.save(f"{output_dir}/P51_merging.heterozygosity.boxplot.html")

# %%
# As a violin plot
# Violin plot but with error bars and means
# Has to be more complicated in order to construct a layered chart that also is faceted
# Variations on the graph can be made my adjusting the scale on the alt.Y of the violin plot

# Varibles to adjust
error_unit = 'stderr' # Can switch extent to `stdev`, `stderr`, or `ci`

# Find ceiling and floor for plot
max_y = df.select(pl.col("Heterozygosity").max().mul(1000).ceil().truediv(1000)).item()
min_y = df.select(pl.col("Heterozygosity").min().mul(1000).floor().truediv(1000)).item()

violin = alt.Chart().transform_density(
    'Heterozygosity',
    as_=['Heterozygosity', 'density'],
    extent=[min_y, max_y],
    groupby=['Cohort']
).mark_area(orient='horizontal').encode(
    alt.X("density:Q").stack('center')
        .impute(None)
        .title(None)
        .axis(labels=False, values=[0], grid=False, ticks=True)
        .scale(nice=False,zero=False),
    alt.Y("Heterozygosity:Q", title='Heterozygosity'),#.scale(domain=[min_y, max_y]),
    # alt.Column("Cohort:N", title="Cohort",
    #       # TODO: Generalize this
    #     ).spacing(0).header(titleOrient='bottom', labelOrient='bottom', labelPadding=0),
    #color=alt.Color("color_idx:N", legend=None).scale(scheme="category10"),
    color=alt.Color("Cohort:N", legend=None).scale(
        domain = list(colors["Cohort"]),
        range = list(colors["Color"])
    )
).properties(
    #width=92
    width=60
)

error = alt.Chart().mark_errorbar(extent=error_unit).encode(
    #alt.X('Cohort', title=None),
    alt.Y('Heterozygosity:Q', title='Heterozygosity')
    )

mean = alt.Chart().mark_circle(color='black').encode(
    #alt.X('Cohort', title=None),
    alt.Y('mean(Heterozygosity):Q', title='Heterozygosity')
    )

layered = alt.layer(violin, error, mean, data=df_with_parental_cohorts
    # .filter(
    # #     # pl.col("Cohort").is_in(["2018-2020", "Offspring of merger", "NEPRC source"]))
    #     pl.col("Cohort").is_in(["Conventional source", "Brooks source", "NEPRC source"]))
).facet(
    #column='Cohort'
    alt.Column('Cohort',
        header=alt.Header(labelOrient='bottom', titleOrient='bottom', labelPadding=0, title='Cohort',), #labelAnchor='end', labelAngle=-90) # labelAngle=-45
        sort=colors["Cohort"]
    )
).resolve_scale(x=alt.ResolveMode("independent")
).configure_facet(
    spacing=0,
).configure_title(anchor='middle').properties(
    #title=["Heterozygosity in", "Founding Populations"]
    title=["Heterozygosity in Cohorts"]
    #title=["Heterozygosity of Merger"]
)

layered.save(f"{output_dir}/P51_merging.heterozygosity.wide_violinplot.html")

# %%
# Same as above, but labels rotated and plot condensed

# Varibles to adjust
error_unit = 'stderr' # Can switch extent to `stdev`, `stderr`, or `ci`

# Find ceiling and floor for plot
max_y = df.select(pl.col("Heterozygosity").max().mul(1000).ceil().truediv(1000)).item()
min_y = df.select(pl.col("Heterozygosity").min().mul(1000).floor().truediv(1000)).item()

violin = alt.Chart().transform_density(
    'Heterozygosity',
    as_=['Heterozygosity', 'density'],
    extent=[min_y, max_y],
    groupby=['Cohort']
).mark_area(orient='horizontal').encode(
    alt.X("density:Q").stack('center')
        .impute(None)
        .title(None)
        .axis(labels=False, values=[0], grid=False, ticks=True)
        .scale(nice=False,zero=False),
    alt.Y("Heterozygosity:Q", title='Heterozygosity'),#.scale(domain=[min_y, max_y]),
    # alt.Column("Cohort:N", title="Cohort",
    #       # TODO: Generalize this
    #     ).spacing(0).header(titleOrient='bottom', labelOrient='bottom', labelPadding=0),
    #color=alt.Color("color_idx:N", legend=None).scale(scheme="category10"),
    color=alt.Color("Cohort:N", legend=None).scale(
        domain = list(colors["Cohort"]),
        range = list(colors["Color"])
    )
).properties(
    width=25
)

error = alt.Chart().mark_errorbar(extent=error_unit).encode(
    #alt.X('Cohort', title=None),
    alt.Y('Heterozygosity:Q', title='Heterozygosity')
    )

mean = alt.Chart().mark_circle(color='black').encode(
    #alt.X('Cohort', title=None),
    alt.Y('mean(Heterozygosity):Q', title='Heterozygosity')
    )

layered = alt.layer(violin, error, mean, data=df_with_parental_cohorts
    # .filter(
    # #     # pl.col("Cohort").is_in(["2018-2020", "Offspring of merger", "NEPRC source"]))
    #     pl.col("Cohort").is_in(["Conventional source", "Brooks source", "NEPRC source"]))
).facet(
    #column='Cohort'
    alt.Column('Cohort',
        header=alt.Header(
            labelOrient='bottom', labelPadding=0, labelAnchor='middle', labelAngle=-90, labelBaseline="middle", labelAlign="right",
            title='Cohort', titleAlign="center", titleOrient='bottom', ),
        sort=colors["Cohort"]
    )
).resolve_scale(x=alt.ResolveMode("independent")
).configure_facet(
    spacing=0,
).configure_title(anchor='middle').properties(
    title=["Heterozygosity in Cohorts"]
)

layered.save(f"{output_dir}/P51_merging.heterozygosity.narrow_violinplot.html")

# %%
from itertools import combinations

import pandas as pd
import scipy

# Do T-test for each pair of cohorts
results = []
for cohort1, cohort2 in combinations(list(df["Cohort"].unique()), 2):
    result = scipy.stats.ttest_ind(
        df.filter(
            pl.col('Cohort') == cohort1
    )['Heterozygosity'],
        df.filter(
            pl.col('Cohort') == cohort2
    )['Heterozygosity'],
    )
    results.append((cohort1, cohort2, result.statistic, result.pvalue, result.df))

stats_df = pd.DataFrame(results, columns=['Cohort1', 'Cohort2', 'Statistc', 'p-Value', 'DF'])
stats_df

# %%
# Remove "U42 sires" since they are already included under "U42"
simplified_colors = colors.filter(~pl.col("Cohort").is_in(["U42 sires", "CPRC dams"]))

# Plot trios to more easily compare offspring to parents
alt.Chart(df2).mark_line().encode(
    alt.X("trio_idx", title='Trio', axis=alt.Axis(labels=False, ticks=False,), scale=alt.Scale(domainMax=df2.select("trio_idx").max().item())),
    alt.Y('Heterozygosity', title='Heterozygosity', scale=alt.Scale(domain=[min_y, max_y])),
    color=alt.Color("Cohort:N").scale(
        domain = list(simplified_colors["Cohort"]),
        range = list(simplified_colors["Color"])
        ),
    tooltip=[
        alt.Tooltip('Id'),
        alt.Tooltip('Relation')
    ]
).properties(
    title="Comparison of Heterozygosity in P51 Offspring and Parents"
).save(f"{output_dir}/P51_offspring_trios.heterozygosity.lineplot.html")

# %%
df2.group_by("trio_idx").agg("*").filter(pl.col("color_idx") == [2, 0, 1])
