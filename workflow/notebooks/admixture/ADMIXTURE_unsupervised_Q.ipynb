# %%
import altair as alt
import polars as pl
import polars.selectors as cs

# Change the k value to run for different k-clusters
# Run first with the ideal value of k before others. That way, the sorting of the others will align with that of the ideal k
k = 3
seed = "899"
project = "rhesus_old"
dataset_subset = 'U42_WES.founders2'
# colonies_tsv = "/master/abagwell/variant-analysis/resources/rhesus/pop/MML_groups_from_Martha.fixed4.with_Brooks_origin.tsv"
colonies_tsv = "/master/abagwell/variant-analysis/resources/rhesus/pop/MML_groups_from_Martha.fixed7.tsv"
#colonies_tsv = "/master/abagwell/variant-analysis/resources/rhesus/pop/CPRC.tsv"


Q = pl.read_csv(
    f"/master/abagwell/variant-analysis/results/{project}/admixture/ADMIXTURE/unsupervised/{dataset_subset}.SNP.autosomal.{k}.{seed}.Q",
    has_header=False, separator=" ")

fam = pl.read_csv(f"/master/abagwell/variant-analysis/results/{project}/genotypes/pruned/plink/{dataset_subset}.SNP.autosomal.fam",
    has_header=False, separator=" ", schema_overrides={"Sample": pl.String, "Sire": pl.String, "Dam": pl.String}, new_columns=["Fam", "Sample", "Sire", "Dam", "Sex", "Phenotype"]
)

demographics = pl.read_csv(f"/master/abagwell/variant-analysis/resources/rhesus/pedigree/demographics.tsv",
    has_header=True, separator="\t", schema_overrides={"Id": pl.String, "Sire": pl.String, "Dam": pl.String},
).with_columns(
    pl.col("Date of Birth").str.split(" ").list.get(0).str.to_date("%Y-%m-%d")
).select("Id", "Date of Birth")

colonies = pl.read_csv(colonies_tsv, columns=["Id", "Origin"],
    has_header=True, separator="\t", schema_overrides={'Id': pl.String} #infer_schema_length=1_000
# ).filter(  # Not necessary for all datasets
#     pl.col("Interval").is_in(["Founders", "Founders2"])
# ).with_columns(
#     pl.concat_str([
#         pl.col("Origin"),
#         pl.lit(" Colony "),
#         pl.col("Colony"),
#     ])
)#.select("Id", "Origin")

# %%
concat_data = pl.concat([fam.select("Sample"), Q], how="horizontal").with_columns(
    # Pull indiv same from larger sample name
    Indiv = pl.col("Sample").str.split("_").list.get(0).str.strip_prefix("WGS").str.strip_prefix("WES")
).drop("Sample"
# Remove any duplicate rows (in case any animals appear twice)
# TODO: Might want to prioritize WGS
).group_by("Indiv").agg(pl.last("*"))

data = concat_data.with_columns(
    admixture = pl.concat_list(pl.exclude('Indiv'))
).with_columns(
    # TODO: Find some way to get the colors to align with those of other clusters when the are similar. Might not be this exact line.
    pops=[f"pop{k}" for k in range(1, k+1)]
).explode("admixture", "pops"
).join(demographics, left_on="Indiv", right_on="Id").select("Indiv", "admixture", "pops", "Date of Birth"
).join(colonies, left_on="Indiv", right_on="Id"
)
#        .with_columns(
#     # Remove non-numeric parts of animal names"
#     pl.col("Indiv").str.replace("8X", "").str.to_integer()
# )

# %%
concat_data

# %%
data#.sort("Origin")

# %%
# For this particular dataset, k=3 has the lowest CV error, so all plots will use this ordering.
# Note that this requires running for k=3 first before other values of k
if k == 3:
    #["column_1", "column_3", "column_2"]
    column_order = ["column_1", "column_2"]
    #column_order = cs.starts_with("column")
    sample_order = concat_data.sort(column_order, descending=False).with_row_index().select("Indiv", "index")
    # .with_columns(
    #     # Remove non-numeric parts of animal names"
    #     pl.col("Indiv").str.replace("8X", "").str.to_integer()
    # )
    # # This is order is saved to a file for use with ADMXITURE_supervised_Q.ipynb
    sample_order#.write_csv("/master/abagwell/variant-analysis/results/rhesus/admixture/ADMIXTURE/unsupervised/unsupervised_order.tsv", separator="\t")

# %%
# Join index to table
data = data.join(sample_order, on="Indiv")

# %%
# Manually switch colors around to let certain values of K match the main one
data = data.with_columns(
    pl.col("pops").replace({
        "pop1": "pop3",
        "pop2": "pop1",
        "pop3": "pop2",
    }),
)

# %%
data

# %%
# # Renaming origins. Probably should change the actual source file
# data = data.with_columns(
#     pl.col("Origin"
#     ).str.replace("non-Brooks Colony 1", "Early founders"
#     ).str.replace("Brooks Colony 1", "Brooks source"
#     ).str.replace("non-Brooks Colony 2", "NEPRC source")
# )

# %%
partitions = data.partition_by("Origin")

# %%
subplots = []
colonies = [partition["Origin"][0] for partition in partitions]

for idx, partition in enumerate(data.partition_by("Origin")):
    if idx == 0:
        axis = alt.Axis()
    else:
        axis = alt.Axis(labels=False, title=None, ticks=False)
    subplot = alt.Chart(partition).mark_bar(width=19).encode(
        alt.X("Indiv:N", title="Animals", axis=alt.Axis(ticks=False, title=None),  #labels=False
              sort=alt.EncodingSortField(field='index', order='ascending')),
        alt.Y("admixture:Q", title=f"k={k}", axis=axis).scale(domain=[0,1]),
        #alt.Column("Origin:N"),
        color=alt.Color("pops:N", title="Population", legend=None),
        tooltip="Indiv",
        # tooltip=[
        #     #alt.Tooltip("Indiv", "Indiv"),
        #     alt.Tooltip("pops", title="Pop")
        # ],
    ).properties(
        title=colonies[idx]
    )
    subplots.append(subplot)

# %%
alt.hconcat(*subplots).configure_range(
        category={'scheme': 'category10'}
).properties(
    #title=f"Unsupervised Admixture of Rhesus Founders, k={k}"
).configure_title(
    anchor="middle"
)#.save(f"/master/abagwell/variant-analysis/results/rhesus/admixture/ADMIXTURE/unsupervised/{dataset_subset}.admixture.barplot.{k}.with_animal_labels.html")
